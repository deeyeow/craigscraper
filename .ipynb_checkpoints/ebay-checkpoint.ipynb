# %% [markdown]
# # Ebay listings visualizer
#
# Visualize the spread of listings on Ebay.

# %%
import requests
from bs4 import BeautifulSoup

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#search = 'razer blade 15 2070'
search = input()
search.replace(' ', '+')
# Out:
# iphone 12
# 'iphone+12'

# %%
URL = 'https://www.ebay.com/sch/i.html?_from=R40&_nkw='
modifier = '&_sacat=0&LH_TitleDesc=0&_ipg=200'

# %%
page = requests.get(URL + search + modifier)

# %%
soup = BeautifulSoup(page.content, 'html.parser')
results = soup.find_all('li', {'class': 's-item s-item--watch-at-corner'})

# %%
names, prices = [], []
counter = 0

for result in results:
    
    # filter bids
    if result.find('span', {'class': 's-item__bids s-item__bidCount'}) is not None: continue
        
    name = result.find('h3', {'class': 's-item__title'}).get_text()
    price = result.find('span', {'class': 's-item__price'}).get_text()
    if 'see price' in price.lower(): continue
    print(name)
    print(price)
    names.append(name)
    
    for ch in [',', '$']:
        if ch in price:
            price = price.replace(ch, '')
            
    prices.append(float(price))
    counter = counter + 1
    
print('\nTotal results:', counter)
# Out:
# New ListingLaunch day - iPhone 12 Pro Max 128gb Pacific Blue - Sealed & Unlocked
# $1,650.00
# New ListingApple iphone 12 Pro 256GB - Gold - FACTORY UNLOCKED
# $1,188.00
# New ListingApple iPhone 12 - 64GB - Black (T-Mobile)
# $700.00
# New ListingApple iPhone 12 - 128GB - Blue (Verizon)
# $799.00
# Apple iPhone 12 Pro - 128GB - Silver (AT&T)
# $979.00
# Apple iPhone 12 - 256GB - Black (Unlocked)  ** BRAND NEW SEALED **
# $968.00
# New ListingiPhone 12 Pro Max 256 Factory Unlocked Pacific Blue In Hand!
# $1,700.00
# New ListingApple iPhone 12 - 64GB - Blue (Unlocked)
# $900.00
# New ListingApple iPhone 12 Pro Max - 128GB - Pacific Blue (Unlocked)
# $1,425.00
# SEALED 2 day shipping Apple iPhone 12 Pro - 128GB - Pacific Blue (Unlocked)!
# $1,274.99
# New ListingApple iPhone 12 - 128GB - Blue (Verizon)
# $865.00
# New ListingApple iPhone 12 - 64GB - Red (Unlocked)
# $899.00
# Apple iPhone 12 (PRODUCT)RED - 128GB (AT&T)
# $800.00
# New ListingApple iPhone 12 Pro - 128GB - Graphite (Unlocked)
# $1,100.00
# Apple iPhone 12 - 128GB - Blue (Unlocked)
# $1,039.00
# New ListingApple iPhone 12 Pro Max - 128GB - Graphite (Unlocked)
# $1,400.00
# Apple iPhone 12 Pro - 256GB - Gold (Unlocked) - Apple Receipt - Ship Worldwide
# $1,715.55
# Apple iPhone 12 Pro - 256GB - Silver (AT&T) Handset Only USPS Priority Shipping
# $1,175.00
# Apple iPhone 12 - 256GB - Blue (Unlocked) WITH AIR PODS!
# $1,300.00
# Apple iPhone 12 Pro - 128GB - Pacific Blue (Unlocked)
# $1,200.00
# Apple iPhone 12 - 128GB - Black (AT&T)
# $850.00
# Apple iPhone 12 Pro Max 256GB - Graphite (read description)
# $5,500.00
# Apple iPhone 12 Pro - 128GB - Gold (Unlocked)
# $1,420.00
# New ListingApple iPhone 12 Pro - 256GB - Pacific Blue (Unlocked)
# $1,600.00
# New Custom Apple iPhone 12 Pro - 512GB - 24K Gold Plated (Unlocked)
# $2,299.00
#
# Total results: 86

# %%
df = pd.DataFrame(
    {'Price': prices
    })

# remove outliers
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
outliers = df[((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# boxplot
fig = plt.figure(1, figsize=(15, 3))
ax = fig.add_subplot(111)
bp = ax.boxplot(df, showmeans=True, manage_ticks=True, vert=False)

ax.set_xlabel('Price')
ax.set_yticks([1])
ax.set_yticklabels([search])

# recalculate quantiles
quantiles = np.quantile(df, np.array([0.00, 0.25, 0.50, 0.75, 1.00]))
quantiles = np.append(quantiles, df.mean()[0])
ax.vlines(quantiles, [0] * quantiles.size, [1] * quantiles.size, color='b', ls=':', lw=0.5, zorder=0)
ax.set_ylim(0.75, 1.25)
ax.set_xticks(quantiles)
plt.show()

# %%
df.describe()
# Out:
#              Price
# count    79.000000
# mean   1171.516456
# std     335.962955
# min     299.000000
# 25%     899.990000
# 50%    1169.000000
# 75%    1394.500000
# max    2000.000000

# %%
outliers
# Out:
#       Price
# 29    33.32
# 45    13.99
# 57    24.99
# 71  6000.00
# 80  4900.00
# 82  5500.00
# 85  2299.00

# %%
def get_threshold(search):
    '''Returns thresholds from file given search query'''

    with open ('data/thresholds.txt') as f:
        for line in f:
            if search in line:
                threshold_lo = int(f.readline())
                threshold_hi = int(f.readline())
                break
    return threshold_lo, threshold_hi

# %%
thresholds=(float('-inf'), float('inf'))
thresholds = (800, 3000)

# initialize lists
prices, price_ints, names, links, badwords = [], [], [], [], []

# get bad words
f = open('data/avoid_keywords.txt')
for line in f:
    badwords.append(line.strip())
f.close()


num_pages = 1
counter = 0

for i in range(num_pages):
    
    URL = 'https://losangeles.craigslist.org/search/sss?query='
    #search = 'razer+blade+15'
    sortby = '&sort=rel'
    if i > 0:
        pgnum = 's=' + str(i * 120) + '&'
    else:
        pgnum = ''
    page = requests.get(URL + pgnum + search + sortby)

    # get soup
    soup = BeautifulSoup(page.content, 'html.parser')
    results = soup.find_all('li', {'class': 'result-row'})

    for result in results:

        # price of individual post
        price = result.find('span', {'class': 'result-meta'}).find('span', {'class': 'result-price'}).get_text()

        # strint to int
        if len(price) == 1: continue
        price_int = int(price.replace(',','')[1:])

        # filter by threshold
        if price_int < thresholds[0] or price_int > thresholds[1] or price_int == 0: continue

        # name
        name = result.find('h3', {'class': 'result-heading'}).find('a').get_text()
        if len(name) == 0: continue

        # filter by bad words
        if any(badkw in name.lower() for badkw in badwords):
            continue

        # link
        link = result.find('a').get('href')
        if len(link) <= 0: continue

        # add result to list
        names.append(name)
        prices.append(price)
        price_ints.append(price_int)
        links.append(link)
        
        counter = counter + 1


for i in range(len(prices)):
    print(names[i])
    print(prices[i])
    #print(links[i])

print(counter)
# Out:
# iPhone 12 Pro 5G 128GB - Graphite (T-Mobile) Brand New
# $800
# Factory Unlocked iPhone 12 Pro 256GB Pacific Blue DELIVERY 10/23
# $1,350
# iPhone 12 Pro Gold 128gb (Unlocked)
# $1,225
# Iphone 12 pro max gold 256 GB $1450
# $1,450
# iPhone 12 Pro 128GB Graphite for AT&T - Brand New, Sealed in Box
# $950
# iPhone 12 Pro Max 512GB Graphite Unlocked
# $1,700
# Apple iPhone 12 Pro Max - 256GB - Pacific Blue [UNLOCKED]
# $1,600
# Apple iPhone 12 Pro Max - 256GB - Graphite [UNLOCKED]
# $1,600
# Sealed + Brand New Unlocked Pacific Blue iPhone 12 Pro 128GB
# $1,300
# iPhone 12 pro
# $1,200
# Apple iPhone 12 pro 128gb
# $1,000
# iphone 12 pro max pre order
# $1,600
# iPhone 12 Pro 128gb or 256gb
# $1,050
# iPhone 12 Pacific Blue 64GB Sealed AT&T
# $850
# iPhone 12 Pro NEW Pacific Blue - UNLOCKED
# $1,300
# iPhone 12 Pro NEW Graphite Black - UNLOCKED
# $1,300
# 16

# %%
df_cg = pd.DataFrame(
    {'Price': price_ints
    })

# remove outliers
Q1 = df_cg.quantile(0.25)
Q3 = df_cg.quantile(0.75)
IQR = Q3 - Q1
outliers = df_cg[((df_cg < (Q1 - 1.5 * IQR)) |(df_cg > (Q3 + 1.5 * IQR))).any(axis=1)]
df_cg = df_cg[~((df_cg < (Q1 - 1.5 * IQR)) |(df_cg > (Q3 + 1.5 * IQR))).any(axis=1)]

# boxplot
fig = plt.figure(1, figsize=(15, 3))
ax = fig.add_subplot(111)
bp = ax.boxplot(df_cg, showmeans=True, manage_ticks=True, vert=False)

ax.set_xlabel('Price')
ax.set_yticks([1])
ax.set_yticklabels([search])

# recalculate quantiles
quantiles = np.quantile(df_cg, np.array([0.00, 0.25, 0.50, 0.75, 1.00]))
quantiles = np.append(quantiles, df_cg.mean()[0])
ax.vlines(quantiles, [0] * quantiles.size, [1] * quantiles.size, color='b', ls=':', lw=0.5, zorder=0)
ax.set_ylim(0.75, 1.25)
ax.set_xticks(quantiles)
plt.show()

# %%
df_cg.describe()
# Out:
#              Price
# count    16.000000
# mean   1267.187500
# std     280.582541
# min     800.000000
# 25%    1037.500000
# 50%    1300.000000
# 75%    1487.500000
# max    1700.000000

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [Price]
# Index: []

# %%
save = df.mean()[0] - df_cg.mean()[0]
print('Average savings on craigslist vs ebay:', save)
print('Percent savings: ', save / df.mean()[0] * 100)
# Out:
# Average savings on craigslist vs ebay: -95.67104430379754
# Percent savings:  -8.166427696224094
